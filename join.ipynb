# %%
import pandas as pd

# %%
summary_df = pd.read_csv('summary-nov6-2024.csv')
metadata = pd.read_csv('zyzhao-list-oct3.csv')

summary_df = summary_df.merge(metadata, on='accession')
summary_df = summary_df['accession,ref_f_unweighted,ref_f_weighted,n_matches,biome3'.split(',')]

# %%
len(summary_df)
# Out:
# 421

# %%
summary_df.sort_values(by='ref_f_weighted')
# Out:
#        accession  ref_f_unweighted  ref_f_weighted  n_matches  \
# 18    ERR1868847          0.188530        0.199830       5854
# 210  SRR12651216          0.207755        0.209558      18112
# 209  SRR12651209          0.215102        0.210860      17438
# 15    ERR1726689          0.256071        0.260921      44442
# 369   SRR6216867          0.226388        0.303323       6321
# ..           ...               ...             ...        ...
# 280  SRR18439529          0.233342             NaN       5181
# 362   SRR5924853          0.270573             NaN      17601
# 381   SRR6403508          0.149671             NaN        788
# 415   SRR8246563          0.050099             NaN       1223
# 417   SRR9182871          0.120143             NaN       1406
#
#                                              biome3
# 18            Host-associated:Fish:Digestive system
# 210           Host-associated:Fish:Digestive system
# 209           Host-associated:Fish:Digestive system
# 15                     Environmental:Aquatic:Marine
# 369                      Host-associated:Human:Skin
# ..                                              ...
# 280  Host-associated:Mammals:Gastrointestinal tract
# 362                    Environmental:Aquatic:Marine
# 381                    Environmental:Aquatic:Marine
# 415           Host-associated:Fish:Digestive system
# 417          Host-associated:Invertebrates:Cnidaria
#
# [421 rows x 5 columns]

# %%
summary_df.sort_values(by='n_matches')[-10:]
# Out:
#        accession  ref_f_unweighted  ref_f_weighted  n_matches  \
# 15    ERR1726689          0.256071        0.260921      44442
# 30    ERR2135519          0.289528        0.652107      45120
# 138   ERR4869744          0.412436        0.458055      45513
# 62    ERR2592280          0.562689        0.706379      45827
# 349   SRR5788051          0.371691        0.549689      45978
# 38    ERR2241717          0.569415        0.747579      46415
# 36    ERR2241714          0.590577        0.741137      49073
# 65    ERR2592342          0.490963        0.684975      51264
# 33    ERR2241633          0.510222        0.735674      55509
# 171  SRR11086695          0.483202        0.549349      56272
#
#                                              biome3
# 15                     Environmental:Aquatic:Marine
# 30   Engineered:Food production:Fermented beverages
# 138                Environmental:Aquatic:Freshwater
# 62           Engineered:Wastewater:Water and sludge
# 349                    Environmental:Aquatic:Marine
# 38          Host-associated:Animal:Digestive system
# 36          Host-associated:Animal:Digestive system
# 65           Engineered:Wastewater:Water and sludge
# 33          Host-associated:Animal:Digestive system
# 171                  Environmental:Terrestrial:Soil

# %%
for i in set(summary_df.sort_values(by='n_matches')[-10:]['accession']):
    print(i)
    #print(f'/group/ctbrowngrp/irber/data/wort-data/wort-sra/sigs/{i}.sig')
# Out:
# ERR4869744
# ERR2241714
# ERR2135519
# SRR11086695
# ERR1726689
# ERR2241717
# ERR2241633
# ERR2592280
# SRR5788051
# ERR2592342
