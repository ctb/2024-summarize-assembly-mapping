# %%
import pandas as pd

# %%
summary_df = pd.read_csv('summary-440.csv')
metadata = pd.read_csv('zyzhao-list-oct3.csv')

summary_df = summary_df.merge(metadata, on='accession')
summary_df = summary_df['accession,ref_f_unweighted,ref_f_weighted,n_matches,biome3'.split(',')]

# %%
len(summary_df)
# Out:
# 433

# %%
summary_df.sort_values(by='ref_f_weighted')
# Out:
#        accession  ref_f_unweighted  ref_f_weighted  n_matches  \
# 14    ERR1868847          0.188530        0.199830       5838
# 211  SRR12651216          0.207755        0.209558      18119
# 210  SRR12651209          0.215102        0.210860      17424
# 150   ERR5094879          0.240174        0.227940      26384
# 335   SRR3988607          0.391362        0.260958        434
# ..           ...               ...             ...        ...
# 340   SRR3989410          0.602926        0.980803        248
# 1     ERR1190729          0.899555        0.981117       3756
# 329   SRR3988554          0.518464        0.983781        320
# 301   SRR3131911          0.864990        0.986999        317
# 212  SRR13169493          0.922077        0.990151       1963
#
#                                              biome3
# 14            Host-associated:Fish:Digestive system
# 211           Host-associated:Fish:Digestive system
# 210           Host-associated:Fish:Digestive system
# 150           Host-associated:Fish:Digestive system
# 335                    Environmental:Aquatic:Lentic
# ..                                              ...
# 340                    Environmental:Aquatic:Lentic
# 1            Host-associated:Human:Digestive system
# 329                    Environmental:Aquatic:Lentic
# 301          Host-associated:Human:Digestive system
# 212  Host-associated:Mammals:Gastrointestinal tract
#
# [433 rows x 5 columns]

# %%
summary_df.sort_values(by='n_matches')[:10]
# Out:
#       accession  ref_f_unweighted  ref_f_weighted  n_matches  \
# 66   ERR2486394          0.209360        0.936130         83
# 65   ERR2486255          0.212460        0.939569        118
# 303  SRR3183382          0.771812        0.900596        119
# 103  ERR2815297          0.173094        0.732617        190
# 104  ERR2815298          0.186004        0.755110        197
# 159   ERR748306          0.981954        0.973540        222
# 342  SRR3989424          0.445407        0.930749        248
# 340  SRR3989410          0.602926        0.980803        248
# 341  SRR3989418          0.596975        0.973500        249
# 349  SRR5164238          0.666298        0.942843        251
#
#                                       biome3
# 66    Host-associated:Birds:Digestive system
# 65    Host-associated:Birds:Digestive system
# 303               Host-associated:Human:Skin
# 103  Host-associated:Animal:Digestive system
# 104  Host-associated:Animal:Digestive system
# 159   Host-associated:Human:Digestive system
# 342             Environmental:Aquatic:Lentic
# 340             Environmental:Aquatic:Lentic
# 341             Environmental:Aquatic:Lentic
# 349   Host-associated:Human:Digestive system

# %%
for i in set(summary_df.sort_values(by='n_matches')[-10:]['accession']):
    print(i)
    #print(f'/group/ctbrowngrp/irber/data/wort-data/wort-sra/sigs/{i}.sig')
# Out:
# SRR5915829
# ERR2592338
# ERR5214467
# ERR2241841
# ERR2241817
# SRR1917411
# ERR2241654
# ERR2245478
# ERR2241793
# ERR4869794

# %%
summary_df[summary_df['accession'] == 'ERR2241825']
# Out:
#      accession  ref_f_unweighted  ref_f_weighted  n_matches  \
# 43  ERR2241825          0.094421             NaN        195
#
#                                      biome3
# 43  Host-associated:Animal:Digestive system
