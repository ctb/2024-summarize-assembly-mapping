# %%
import pandas as pd

# %%
summary_df = pd.read_csv('summary-nov11-2024.csv')
metadata = pd.read_csv('zyzhao-list-oct3.csv')

summary_df = summary_df.merge(metadata, on='accession')
summary_df = summary_df['accession,ref_f_unweighted,ref_f_weighted,n_matches,biome3'.split(',')]

# %%
len(summary_df)
# Out:
# 1916

# %%
summary_df.sort_values(by='ref_f_weighted')
# Out:
#         accession  ref_f_unweighted  ref_f_weighted  n_matches  \
# 714    ERR5094878          0.176925        0.179968      30014
# 1556   SRR3989348          0.566692        0.195240        292
# 84     ERR1868847          0.188530        0.199830       5838
# 1022  SRR12651214          0.211358        0.201631      18878
# 717    ERR5094886          0.208238        0.201821      35402
# ...           ...               ...             ...        ...
# 1424   SRR3131911          0.864990        0.986999        317
# 1037  SRR13169517          0.927473        0.987221       2139
# 1562   SRR3989393          0.560673        0.988120        211
# 1034  SRR13169493          0.922077        0.990151       1963
# 1038  SRR13169518          0.804973        0.991203        819
#
#                                               biome3
# 714            Host-associated:Fish:Digestive system
# 1556                    Environmental:Aquatic:Lentic
# 84             Host-associated:Fish:Digestive system
# 1022           Host-associated:Fish:Digestive system
# 717            Host-associated:Fish:Digestive system
# ...                                              ...
# 1424          Host-associated:Human:Digestive system
# 1037  Host-associated:Mammals:Gastrointestinal tract
# 1562                    Environmental:Aquatic:Lentic
# 1034  Host-associated:Mammals:Gastrointestinal tract
# 1038  Host-associated:Mammals:Gastrointestinal tract
#
# [1916 rows x 5 columns]

# %%
summary_df.sort_values(by='n_matches')[:10]
# Out:
#        accession  ref_f_unweighted  ref_f_weighted  n_matches  \
# 1406  SRR2145647          0.750000        0.750000          3
# 267   ERR2486219          0.700000        0.934783          6
# 257   ERR2261893          0.404255        0.916867         18
# 273   ERR2486310          0.243243        0.950227         44
# 266   ERR2486216          0.269841        0.958773         49
# 265   ERR2486211          0.232932        0.959374         55
# 590    ERR346236          0.906037        0.932914         66
# 274   ERR2486316          0.202247        0.975712         68
# 701   ERR5084157          0.896679        0.889231         78
# 271   ERR2486295          0.208134        0.825183         82
#
#                                         biome3
# 1406    Host-associated:Human:Digestive system
# 267     Host-associated:Birds:Digestive system
# 257     Host-associated:Human:Digestive system
# 273     Host-associated:Birds:Digestive system
# 266     Host-associated:Birds:Digestive system
# 265     Host-associated:Birds:Digestive system
# 590   Host-associated:Mammals:Digestive system
# 274     Host-associated:Birds:Digestive system
# 701                 Host-associated:Human:Skin
# 271     Host-associated:Birds:Digestive system

# %%
for i in set(summary_df.sort_values(by='n_matches')[-10:]['accession']):
    print(i)
    #print(f'/group/ctbrowngrp/irber/data/wort-data/wort-sra/sigs/{i}.sig')
# Out:
# ERR2592250
# SRR12358625
# ERR4691814
# ERR2597490
# ERR598947
# ERR1726918
# SRR5468194
# ERR1726712
# SRR9182858
# ERR2597525

# %%
summary_df[summary_df['accession'] == 'ERR2241825']
# Out:
#       accession  ref_f_unweighted  ref_f_weighted  n_matches  \
# 201  ERR2241825          0.513327        0.597761      47024
#
#                                       biome3
# 201  Host-associated:Animal:Digestive system
